# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="Rossum"></p>
#
#
# ____

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
ecom = pd.read_csv('/content/drive/MyDrive/data.csv',encoding= 'unicode_escape')

# %% [markdown]
# **Check the head of the DataFrame.**

# %%
ecom.head()
# Out:
#   InvoiceNo StockCode  ... CustomerID         Country
# 0    536365    85123A  ...    17850.0  United Kingdom
# 1    536365     71053  ...    17850.0  United Kingdom
# 2    536365    84406B  ...    17850.0  United Kingdom
# 3    536365    84029G  ...    17850.0  United Kingdom
# 4    536365    84029E  ...    17850.0  United Kingdom
#
# [5 rows x 8 columns]

# %% [markdown]
# ** How many rows and columns are there? **

# %%
ecom.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
<class 'pandas.core.frame.DataFrame'>
RangeIndex: 541909 entries, 0 to 541908
Data columns (total 8 columns):
 #   Column       Non-Null Count   Dtype  
---  ------       --------------   -----  
 0   InvoiceNo    541909 non-null  object 
 1   StockCode    541909 non-null  object 
 2   Description  540455 non-null  object 
 3   Quantity     541909 non-null  int64  
 4   InvoiceDate  541909 non-null  object 
 5   UnitPrice    541909 non-null  float64
 6   CustomerID   406829 non-null  float64
 7   Country      541909 non-null  object 
dtypes: float64(2), int64(1), object(5)
memory usage: 33.1+ MB

# %% [markdown]
# ** Show the statistical measurements of ecom dataset **

# %%
ecom.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %% [markdown]
# ** What is the average Purchase Price? **

# %%
ecom["UnitPrice"].mean()
# Out:
# 4.611113626083471

# %% [markdown]
# ** What were the highest and lowest purchase prices? **

# %%
ecom["UnitPrice"].max()
# Out:
# 38970.0

# %%
ecom["UnitPrice"].min()
# Out:
# -11062.06

# %% [markdown]
# ** List the country names and number of records belongs to each country **

# %%
ecom["Country"].value_counts()
# Out:
# United Kingdom          495478
# Germany                   9495
# France                    8557
# EIRE                      8196
# Spain                     2533
# Netherlands               2371
# Belgium                   2069
# Switzerland               2002
# Portugal                  1519
# Australia                 1259
# Norway                    1086
# Italy                      803
# Channel Islands            758
# Finland                    695
# Cyprus                     622
# Sweden                     462
# Unspecified                446
# Austria                    401
# Denmark                    389
# Japan                      358
# Poland                     341
# Israel                     297
# USA                        291
# Hong Kong                  288
# Singapore                  229
# Iceland                    182
# Canada                     151
# Greece                     146
# Malta                      127
# United Arab Emirates        68
# European Community          61
# RSA                         58
# Lebanon                     45
# Lithuania                   35
# Brazil                      32
# Czech Republic              30
# Bahrain                     19
# Saudi Arabia                10
# Name: Country, dtype: int64

# %% [markdown]
# ** How many records are as Country United Kingdom? **

# %%
ecom[ecom["Country"]== "United Kingdom"].count()
# Out:
# InvoiceNo      495478
# StockCode      495478
# Description    494024
# Quantity       495478
# InvoiceDate    495478
# UnitPrice      495478
# CustomerID     361878
# Country        495478
# dtype: int64

# %% [markdown]
# ** Create a column named Total which shows the total amount of spend
#
# ---
#
# using UnitPrice and Quantity ? **

# %%
ecom["Total"]=ecom["Quantity"] * ecom["UnitPrice"]
ecom["Total"]
# Out:
# 0         15.30
# 1         20.34
# 2         22.00
# 3         20.34
# 4         20.34
#           ...
# 541904    10.20
# 541905    12.60
# 541906    16.60
# 541907    16.60
# 541908    14.85
# Name: Total, Length: 541909, dtype: float64

# %% [markdown]
# ** Show total pending amount according to the Countries **

# %%
ecom.groupby(["Country"]).Total.sum().round(2)
# Out:
# Country
# Australia                137077.27
# Austria                   10154.32
# Bahrain                     548.40
# Belgium                   40910.96
# Brazil                     1143.60
# Canada                     3666.38
# Channel Islands           20086.29
# Cyprus                    12946.29
# Czech Republic              707.72
# Denmark                   18768.14
# EIRE                     263276.82
# European Community         1291.75
# Finland                   22326.74
# France                   197403.90
# Germany                  221698.21
# Greece                     4710.52
# Hong Kong                 10117.04
# Iceland                    4310.00
# Israel                     7907.82
# Italy                     16890.51
# Japan                     35340.62
# Lebanon                    1693.88
# Lithuania                  1661.06
# Malta                      2505.47
# Netherlands              284661.54
# Norway                    35163.46
# Poland                     7213.14
# Portugal                  29367.02
# RSA                        1002.31
# Saudi Arabia                131.17
# Singapore                  9120.39
# Spain                     54774.58
# Sweden                    36595.91
# Switzerland               56385.35
# USA                        1730.92
# United Arab Emirates       1902.28
# United Kingdom          8187806.36
# Unspecified                4749.79
# Name: Total, dtype: float64

# %% [markdown]
# ** Which Country spend least? **

# %%
ecom.groupby("Country").Total.sum().min()
# Out:
# 131.17

# %%
ecom.groupby("Country").Total.sum().agg(["min"])
# Out:
# min    131.17
# Name: Total, dtype: float64

# %% [markdown]
# ** Calculate average of spending according to country with apply function? **

# %%
ecom.groupby("Country").Total.agg(["mean"])
# Out:
#                             mean
# Country
# Australia             108.877895
# Austria                25.322494
# Bahrain                28.863158
# Belgium                19.773301
# Brazil                 35.737500
# Canada                 24.280662
# Channel Islands        26.499063
# Cyprus                 20.813971
# Czech Republic         23.590667
# Denmark                48.247147
# EIRE                   32.122599
# European Community     21.176230
# Finland                32.124806
# France                 23.069288
# Germany                23.348943
# Greece                 32.263836
# Hong Kong              35.128611
# Iceland                23.681319
# Israel                 26.625657
# Italy                  21.034259
# Japan                  98.716816
# Lebanon                37.641778
# Lithuania              47.458857
# Malta                  19.728110
# Netherlands           120.059696
# Norway                 32.378877
# Poland                 21.152903
# Portugal               19.333127
# RSA                    17.281207
# Saudi Arabia           13.117000
# Singapore              39.827031
# Spain                  21.624390
# Sweden                 79.211926
# Switzerland            28.164510
# USA                     5.948179
# United Arab Emirates   27.974706
# United Kingdom         16.525065
# Unspecified            10.649753

# %%
Country
Australia               108.877895
Austria                  25.322494
Bahrain                  28.863158
Belgium                  19.773301
Brazil                   35.737500
Canada                   24.280662
Channel Islands          26.499063
Cyprus                   20.813971
Czech Republic           23.590667
Denmark                  48.247147
EIRE                     32.122599
European Community       21.176230
Finland                  32.124806
France                   23.069288
Germany                  23.348943
Greece                   32.263836
Hong Kong                35.128611
Iceland                  23.681319
Israel                   26.625657
Italy                    21.034259
Japan                    98.716816
Lebanon                  37.641778
Lithuania                47.458857
Malta                    19.728110
Netherlands             120.059696
Norway                   32.378877
Poland                   21.152903
Portugal                 19.333127
RSA                      17.281207
Saudi Arabia             13.117000
Singapore                39.827031
Spain                    21.624390
Sweden                   79.211926
Switzerland              28.164510
USA                       5.948179
United Arab Emirates     27.974706
United Kingdom           16.525065
Unspecified              10.649753
Name: Total, dtype: float64

# %% [markdown]
# ** Calculate average,min,max of spending according to country with agg function? **

# %%
ecom.groupby("Country").Total.agg(["mean","min","max"])
# Out:
#                             mean        min        max
# Country
# Australia             108.877895    -425.00    1718.40
# Austria                25.322494     -21.25     360.00
# Bahrain                28.863158    -205.74     205.74
# Belgium                19.773301     -19.95     165.00
# Brazil                 35.737500      15.00     175.20
# Canada                 24.280662       2.50     550.94
# Channel Islands        26.499063    -293.00     408.00
# Cyprus                 20.813971    -320.69     320.69
# Czech Republic         23.590667     -35.76      70.80
# Denmark                48.247147     -59.80     428.40
# EIRE                   32.122599   -1917.00    2365.20
# European Community     21.176230      -8.50      60.00
# Finland                32.124806     -80.00     551.20
# France                 23.069288   -8322.12    4161.06
# Germany                23.348943    -599.50     876.00
# Greece                 32.263836     -50.00     175.20
# Hong Kong              35.128611   -2653.95    2653.95
# Iceland                23.681319       5.04     249.60
# Israel                 26.625657    -136.00     350.40
# Italy                  21.034259     -89.55     300.00
# Japan                  98.716816   -1591.20    3794.40
# Lebanon                37.641778      10.20     153.00
# Lithuania              47.458857      13.20     122.40
# Malta                  19.728110    -130.00     455.00
# Netherlands           120.059696    -266.40    4992.00
# Norway                 32.378877    -376.50     700.00
# Poland                 21.152903     -39.80     120.00
# Portugal               19.333127   -1241.98    1241.98
# RSA                    17.281207       0.00      38.25
# Saudi Arabia           13.117000     -14.75      19.80
# Singapore              39.827031   -3949.32    3949.32
# Spain                  21.624390   -1715.85    1350.00
# Sweden                 79.211926   -1188.00    1188.00
# Switzerland            28.164510    -179.00     360.00
# USA                     5.948179     -74.88      81.36
# United Arab Emirates   27.974706       3.48     153.00
# United Kingdom         16.525065 -168469.60  168469.60
# Unspecified            10.649753       0.19      69.36

# %% [markdown]
# ** What is the max Total spending in whole dataset and show the records of that spending ?**

# %%
ecom.groupby("Country").Total.agg(["max"]).max()
# Out:
# max    168469.6
# dtype: float64

# %%
ecom[ecom["Total"]==168469.6]
# Out:
#        InvoiceNo StockCode  ...         Country     Total
# 540421    581483     23843  ...  United Kingdom  168469.6
#
# [1 rows x 9 columns]

# %%
ecom["Total"].mean()
# Out:
# 17.987794877005495

# %% [markdown]
# ** How many people who live in Spain spend more than average Total ?**
#
# > Girintili blok

# %%
ecom[(ecom["Country"]=="Spain")& (ecom["Total"]>17.987794877005495)].count()
# Out:
# InvoiceNo      728
# StockCode      728
# Description    728
# Quantity       728
# InvoiceDate    728
# UnitPrice      728
# CustomerID     728
# Country        728
# Total          728
# dtype: int64

# %% [markdown]
# ** Convert datatype of InvoiceDate to datetime and assign it to new column name InvoiceDate2**

# %%
ecom["InvoiceDate"] == pd.to_datetime(ecom["InvoiceDate"])
ecom["InvoiceDate2"] = ecom["InvoiceDate"]
ecom["InvoiceDate2"].astype('datetime64')
# Out:
# 0        2010-12-01 08:26:00
# 1        2010-12-01 08:26:00
# 2        2010-12-01 08:26:00
# 3        2010-12-01 08:26:00
# 4        2010-12-01 08:26:00
#                  ...
# 541904   2011-12-09 12:50:00
# 541905   2011-12-09 12:50:00
# 541906   2011-12-09 12:50:00
# 541907   2011-12-09 12:50:00
# 541908   2011-12-09 12:50:00
# Name: InvoiceDate2, Length: 541909, dtype: datetime64[ns]

# %%
from datetime import datetime
import seaborn as sns

# %% [markdown]
# ** Take only date values (year-month-day) from InvoiceDate2 and assign it to a new column named date **

# %%
ecom['Date'] = ecom["InvoiceDate2"].astype('datetime64').dt.date
ecom['Date']
# Out:
# 0         2010-12-01
# 1         2010-12-01
# 2         2010-12-01
# 3         2010-12-01
# 4         2010-12-01
#              ...
# 541904    2011-12-09
# 541905    2011-12-09
# 541906    2011-12-09
# 541907    2011-12-09
# 541908    2011-12-09
# Name: Date, Length: 541909, dtype: object

# %%
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country  Total  \
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom  15.30
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom  20.34
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom  22.00
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom  20.34
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom  20.34
#
#          InvoiceDate2        date
# 0 2010-12-01 08:26:00  2010-12-01
# 1 2010-12-01 08:26:00  2010-12-01
# 2 2010-12-01 08:26:00  2010-12-01
# 3 2010-12-01 08:26:00  2010-12-01
# 4 2010-12-01 08:26:00  2010-12-01

# %%
ecom.drop("InvoiceDate2", axis=1)
# Out:
#        InvoiceNo StockCode  ...  Total        Date
# 0         536365    85123A  ...  15.30  2010-12-01
# 1         536365     71053  ...  20.34  2010-12-01
# 2         536365    84406B  ...  22.00  2010-12-01
# 3         536365    84029G  ...  20.34  2010-12-01
# 4         536365    84029E  ...  20.34  2010-12-01
# ...          ...       ...  ...    ...         ...
# 541904    581587     22613  ...  10.20  2011-12-09
# 541905    581587     22899  ...  12.60  2011-12-09
# 541906    581587     23254  ...  16.60  2011-12-09
# 541907    581587     23255  ...  16.60  2011-12-09
# 541908    581587     22138  ...  14.85  2011-12-09
#
# [541909 rows x 10 columns]

# %%
ecom.drop(["InvoiceDate","InvoiceDate2"], inplace=True ,axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-68-6ac713cf38f4> in <module>()
# ----> 1 ecom.drop(["InvoiceDate","InvoiceDate2"], inplace=True ,axis=1)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4172             level=level,
#    4173             inplace=inplace,
# -> 4174             errors=errors,
#    4175         )
#    4176
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3887         for axis, labels in axes.items():
#    3888             if labels is not None:
# -> 3889                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3890
#    3891         if inplace:
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3921                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3922             else:
# -> 3923                 new_axis = axis.drop(labels, errors=errors)
#    3924             result = self.reindex(**{axis_name: new_axis})
#    3925
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    5285         if mask.any():
#    5286             if errors != "ignore":
# -> 5287                 raise KeyError(f"{labels[mask]} not found in axis")
#    5288             indexer = indexer[~mask]
#    5289         return self.delete(indexer)
#
# KeyError: "['InvoiceDate' 'InvoiceDate2'] not found in axis"

# %%
#Kodu iki kez çalıştırdım ondan yukarıdaki hatayı verdi. Zaten silmişti.

# %%
ecom
# Out:
#        InvoiceNo StockCode  ...  Total        Date
# 0         536365    85123A  ...  15.30  2010-12-01
# 1         536365     71053  ...  20.34  2010-12-01
# 2         536365    84406B  ...  22.00  2010-12-01
# 3         536365    84029G  ...  20.34  2010-12-01
# 4         536365    84029E  ...  20.34  2010-12-01
# ...          ...       ...  ...    ...         ...
# 541904    581587     22613  ...  10.20  2011-12-09
# 541905    581587     22899  ...  12.60  2011-12-09
# 541906    581587     23254  ...  16.60  2011-12-09
# 541907    581587     23255  ...  16.60  2011-12-09
# 541908    581587     22138  ...  14.85  2011-12-09
#
# [541909 rows x 9 columns]

# %% [markdown]
# ** drop InvoiceDate2 and InvoiceDate columns permanently **

# %%
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#    UnitPrice  CustomerID         Country  Total        date
# 0       2.55     17850.0  United Kingdom  15.30  2010-12-01
# 1       3.39     17850.0  United Kingdom  20.34  2010-12-01
# 2       2.75     17850.0  United Kingdom  22.00  2010-12-01
# 3       3.39     17850.0  United Kingdom  20.34  2010-12-01
# 4       3.39     17850.0  United Kingdom  20.34  2010-12-01

# %%
type(ecom["StockCode"])
# Out:
# pandas.core.series.Series

# %% [markdown]
# ** Remove A, B, G and E from StockCode in first 5 rows of ecom dataframe with a string method **

# %%
ecom["StockCode"].str[:-1].head()
# Out:
# 0    85123
# 1     7105
# 2    84406
# 3    84029
# 4    84029
# Name: StockCode, dtype: object

# %%
ecom["StockCode"].str[:-1].head()
# Out:
# 0    85123
# 1     7105
# 2    84406
# 3    84029
# 4    84029
# Name: StockCode, dtype: object

# %%
0    85123
1    71053
2    84406
3    84029
4    84029
Name: StockCode, dtype: object

# %% [markdown]
# ** take only Total and date columns with loc and craete a new df named ecom2 **

# %%
ecom2=ecom.loc[:,("Total","Date")]
ecom2
# Out:
#         Total        Date
# 0       15.30  2010-12-01
# 1       20.34  2010-12-01
# 2       22.00  2010-12-01
# 3       20.34  2010-12-01
# 4       20.34  2010-12-01
# ...       ...         ...
# 541904  10.20  2011-12-09
# 541905  12.60  2011-12-09
# 541906  16.60  2011-12-09
# 541907  16.60  2011-12-09
# 541908  14.85  2011-12-09
#
# [541909 rows x 2 columns]

# %% [markdown]
# ** take only InvoiceNo, CustomerID and Total columns with iloc and craete a new df named ecom3 **

# %%
ecom3=ecom.iloc[:,[0,6,8]]
ecom3
# Out:
#        InvoiceNo  CustomerID  Total
# 0         536365     17850.0  15.30
# 1         536365     17850.0  20.34
# 2         536365     17850.0  22.00
# 3         536365     17850.0  20.34
# 4         536365     17850.0  20.34
# ...          ...         ...    ...
# 541904    581587     12680.0  10.20
# 541905    581587     12680.0  12.60
# 541906    581587     12680.0  16.60
# 541907    581587     12680.0  16.60
# 541908    581587     12680.0  14.85
#
# [541909 rows x 3 columns]

# %%
 	InvoiceNo 	CustomerID 	Total
0 	536365 	17850.0 	15.30
1 	536365 	17850.0 	20.34
2 	536365 	17850.0 	22.00
3 	536365 	17850.0 	20.34
4 	536365 	17850.0 	20.34
... 	... 	... 	...
541904 	581587 	12680.0 	10.20
541905 	581587 	12680.0 	12.60
541906 	581587 	12680.0 	16.60
541907 	581587 	12680.0 	16.60
541908 	581587 	12680.0 	14.85

541909 rows × 3 columns

# %% [markdown]
# ** Combine ecom2 and ecom3 with concat **

# %%
pd.concat([ecom2,ecom3])
# Out:
#         Total        Date InvoiceNo  CustomerID
# 0       15.30  2010-12-01       NaN         NaN
# 1       20.34  2010-12-01       NaN         NaN
# 2       22.00  2010-12-01       NaN         NaN
# 3       20.34  2010-12-01       NaN         NaN
# 4       20.34  2010-12-01       NaN         NaN
# ...       ...         ...       ...         ...
# 541904  10.20         NaN    581587     12680.0
# 541905  12.60         NaN    581587     12680.0
# 541906  16.60         NaN    581587     12680.0
# 541907  16.60         NaN    581587     12680.0
# 541908  14.85         NaN    581587     12680.0
#
# [1083818 rows x 4 columns]

# %% [markdown]
# ** Combine ecom2 and ecom3 with merge. If memory error occurs take only first 400 rows from both DFs.**

# %%
pd.merge(ecom2,ecom3)

# %% [markdown]
# ** Combine ecom2 and ecom3 with join (inner)**

# %%
ecom2.join(ecom3, on="Total", how="inner", lsuffix="_l", rsuffix="_r" )
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/reshape/merge.py:1117: UserWarning: You are merging on int and float columns where the float values are not equal to their int representation
#   UserWarning,
#          Total  Total_l        Date InvoiceNo  CustomerID  Total_r
# 2         22.0     22.0  2010-12-01    536368     13047.0    14.85
# 51        22.0     22.0  2010-12-01    536368     13047.0    14.85
# 68        22.0     22.0  2010-12-01    536368     13047.0    14.85
# 280       22.0     22.0  2010-12-01    536368     13047.0    14.85
# 418       22.0     22.0  2010-12-01    536368     13047.0    14.85
# ...        ...      ...         ...       ...         ...      ...
# 526144   237.0    237.0  2011-12-05   C536391     17548.0    -6.96
# 533627  1170.0   1170.0  2011-12-07    536528     15525.0     5.90
# 533734  1581.0   1581.0  2011-12-07    536544         NaN    13.54
# 533741  2046.0   2046.0  2011-12-07    536557     17841.0     2.55
# 533812  3861.0   3861.0  2011-12-07    536707     12915.0    15.90
#
# [55084 rows x 6 columns]

# %% [markdown]
# # Congrats!
